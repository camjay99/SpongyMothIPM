# %%
import rasterio as rio
from rasterio.plot import show
import numpy as np

# %%
with rio.open('../data/cmip6/ACCESS-CM2_ssp245_2086_1_7.tif') as src:
    show(src)
    test = src.read(1)

# %%
np.all(test == 0)
# Out:
# np.False_

# %%
np.unique(test)
# Out:
# array([  -inf, 30836., 30869., ..., 35376., 35414., 35455.], shape=(2475,))
